# %% [markdown]
# <a href="https://colab.research.google.com/github/sjsepulveda0108-coder/Fundamentos_de_Programaci-n_-Santiago_Jaramillo/blob/main/Homework_1_Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 2 · Tarea 01 — 8 ejercicios autocalificables
#
# ### Variables, tipos de datos, operadores y condicionales
#
# **Instrucciones**
#
# 1. Implementa cada función en la celda `# ✏️ TU CÓDIGO AQUÍ`
#    (reemplaza la línea `raise NotImplementedError`).
# 2. **No cambies el nombre ni los parámetros** de las funciones.
# 3. Ejecuta las celdas de tests visibles y adicionales. Deben pasar sin error.
# 4. Tu objetivo: que **todas** las celdas de tests muestren ✅.
#
# > 🔎 Antes de programar, escribe el pseudocódigo y traza un ejemplo a mano.
#
# > ⚠️ Esta tarea **no** corre de principio a fin hasta que implementes cada función.
#
# **Conceptos ejercitados:** operadores `//` y `%`, condicionales escalonados,
# type casting, operadores lógicos, validación de casos borde.

# %%
# Identifícate (esto ayuda si entregas el notebook).
NOMBRE = "Santiago Jaramillo Sepulveda"   # ✏️ escribe tu nombre completo
print("Tarea lista para resolver. Ejecuta cada bloque de tests tras implementar.")

# %% [markdown]
# ## Ejercicio 1 · Días entre dos años
#
# Implementa `dias_entre_anios(anio_inicio, anio_fin)` que devuelva el número total de días entre el 1 de enero de `anio_inicio` y el 1 de enero de `anio_fin`.
#
# **Sin librerías de fecha.** Usa aritmética: recorre cada año y suma 366 si es bisiesto, 365 si no.
#
# Un año es bisiesto si: `(anio % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0)`.
#
# **Ejemplo:** `dias_entre_anios(2020, 2023)` → `1096`
# (2020 tiene 366 días + 2021 tiene 365 + 2022 tiene 365 = 1096).

# %%
recibir anio_inicio y anio_fin
crear una lista vacía llamada dias

por cada año d desde anio_inicio hasta anio_fin (sin incluirlo):
   si (d es divisible por 4 y NO es divisible por 100)
      o (d es divisible por 400):
       agregar 366 a la lista dias
   si no:
       agregar 365 a la lista dias

devolver la suma de todos los elementos de la lista dias

# %%
def dias_entre_anios(anio_inicio, anio_fin):
    dias = []
    for d in range(anio_inicio, anio_fin):
        if (d % 4 == 0 and d % 100 != 0) or (d % 400 == 0):
            dias.append(366)
        else:
            dias.append(365)
    return sum(dias)

# %%
# === Tests visibles · Ejercicio 1 ===
assert dias_entre_anios(2020, 2023) == 1096
assert dias_entre_anios(2023, 2024) == 365
print("✅ Ejercicio 1: tests visibles superados.")
# Out:
# ✅ Ejercicio 1: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 1 ===
assert dias_entre_anios(2000, 2001) == 366
assert dias_entre_anios(1900, 1901) == 365
assert dias_entre_anios(2024, 2024) == 0
print("✅ Ejercicio 1: tests adicionales superados.")
# Out:
# ✅ Ejercicio 1: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 2 · Tipo de triángulo
#
# Implementa `tipo_triangulo(a, b, c)` que clasifique el triángulo según sus lados:
# - `'equilatero'` si los tres lados son iguales.
# - `'isosceles'` si exactamente dos lados son iguales.
# - `'escaleno'` si ningún lado es igual a otro.
# - `'invalido'` si los lados no forman un triángulo (la suma de dos lados cualquiera debe ser mayor al tercero).
#
# **Ejemplos:** `tipo_triangulo(5, 5, 5)` → `'equilatero'`; `tipo_triangulo(3, 3, 5)` → `'isosceles'`; `tipo_triangulo(3, 4, 5)` → `'escaleno'`; `tipo_triangulo(1, 2, 10)` → `'invalido'`.

# %%
recibir a, b, c

si a es menor o igual a 0, o b es menor o igual a 0,
  o c es menor o igual a 0:
   devolver 'invalido'

si (a + b es menor o igual a c)
  o (a + c es menor o igual a b)
  o (b + c es menor o igual a a):
   devolver 'invalido'

si a es igual a b y b es igual a c:
   devolver 'equilatero'

si (a es igual a b y a es distinto de c)
  o (a es igual a c y a es distinto de b)
  o (b es igual a c y c es distinto de a):
   devolver 'isosceles'

devolver 'escaleno'

# %%
def tipo_triangulo(a, b, c):
    if a <= 0 or b <= 0 or c <= 0:
        return "invalido"
    if a + b <= c or a + c <= b or b + c <= a:
        return "invalido"
    if a == b == c:
        return "equilatero"
    if (a == b and a != c) or (a == c and a != b) or (b == c and c != a):
        return "isosceles"
    return "escaleno"

# %%
# === Tests visibles · Ejercicio 2 ===
assert tipo_triangulo(5, 5, 5) == 'equilatero'
assert tipo_triangulo(3, 3, 5) == 'isosceles'
assert tipo_triangulo(3, 4, 5) == 'escaleno'
assert tipo_triangulo(1, 2, 10) == 'invalido'
print("✅ Ejercicio 2: tests visibles superados.")
# Out:
# ✅ Ejercicio 2: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 2 ===
assert tipo_triangulo(0, 0, 0) == 'invalido'
assert tipo_triangulo(7, 7, 9) == 'isosceles'
assert tipo_triangulo(6, 8, 10) == 'escaleno'
assert tipo_triangulo(1, 1, 2) == 'invalido'
print("✅ Ejercicio 2: tests adicionales superados.")
# Out:
# ✅ Ejercicio 2: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 3 · Índice de rentabilidad
#
# Implementa `rentabilidad(precio_compra, precio_venta)` que devuelva:
# - El **porcentaje de ganancia o pérdida** sobre el precio de compra,
#   redondeado a 4 decimales.
# - Formula: `(precio_venta - precio_compra) / precio_compra`
#
# - Si `precio_compra <= 0`, devuelve `None`.
#
# **Ejemplos:** `rentabilidad(1000000, 1200000)` → `0.2` (ganancia 20%);
# `rentabilidad(1000000, 800000)` → `-0.2` (pérdida 20%).

# %%
recibir precio_compra y precio_venta

si precio_compra es menor o igual a 0:
   guardar None en rentabilidad
si no:
   guardar (precio_venta - precio_compra) / precio_compra en rentabilidad

devolver rentabilidad

# %%
def rentabilidad(precio_compra, precio_venta):
    if precio_compra <= 0:
      rentabilidad = None
    else:
      rentabilidad = (precio_venta - precio_compra) / precio_compra
    return rentabilidad

# %%
# === Tests visibles · Ejercicio 3 ===
assert rentabilidad(1000000, 1200000) == 0.2
assert rentabilidad(1000000, 800000) == -0.2
print("✅ Ejercicio 3: tests visibles superados.")
# Out:
# ✅ Ejercicio 3: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 3 ===
assert rentabilidad(500000, 500000) == 0.0
assert rentabilidad(0, 100000) is None
assert rentabilidad(200000, 250000) == 0.25
print("✅ Ejercicio 3: tests adicionales superados.")
# Out:
# ✅ Ejercicio 3: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 4 · Clasificar nota universitaria
#
# Implementa `clasificar_nota(nota)` que devuelva la clasificación de una nota:
# - `'reprobado'` si `nota < 3.0`
# - `'aprobado'` si `3.0 <= nota < 4.0`
# - `'bueno'` si `4.0 <= nota < 4.5`
# - `'excelente'` si `nota >= 4.5`
#
# **Nota:** la escala es de 0 a 5. Si la nota está fuera de `[0, 5]`, devuelve `'fuera de rango'`.
#
# **Ejemplos:** `clasificar_nota(2.5)` → `'reprobado'`; `clasificar_nota(3.8)` → `'aprobado'`; `clasificar_nota(4.7)` → `'excelente'`.

# %%
recibir nota

si nota es menor que 0 o mayor que 5:
   devolver 'fuera de rango'
si no, si nota es menor que 3.0:
   devolver 'reprobado'
si no, si nota está entre 3.0 y menor que 4.0:
   devolver 'aprobado'
si no, si nota está entre 4.0 y menor que 4.5:
   devolver 'bueno'

devolver 'excelente'

# %%
def clasificar_nota(nota):
    if nota < 0 or nota > 5:
        return "fuera de rango"
    elif nota < 3.0:
        return "reprobado"
    elif 3.0 <= nota < 4.0:
        return "aprobado"
    elif 4.0 <= nota < 4.5:
        return "bueno"
    else:
        return "excelente"

# %%
# === Tests visibles · Ejercicio 4 ===
assert clasificar_nota(2.5) == 'reprobado'
assert clasificar_nota(3.8) == 'aprobado'
assert clasificar_nota(4.7) == 'excelente'
print("✅ Ejercicio 4: tests visibles superados.")
# Out:
# ✅ Ejercicio 4: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 4 ===
assert clasificar_nota(0.0) == 'reprobado'
assert clasificar_nota(3.0) == 'aprobado'
assert clasificar_nota(4.0) == 'bueno'
assert clasificar_nota(4.5) == 'excelente'
assert clasificar_nota(5.0) == 'excelente'
assert clasificar_nota(-1) == 'fuera de rango'
assert clasificar_nota(6) == 'fuera de rango'
print("✅ Ejercicio 4: tests adicionales superados.")
# Out:
# ✅ Ejercicio 4: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 5 · Interés simple
#
# Implementa `interes_simple(capital, tasa, tiempo)` que devuelva una tupla `(interes, monto_total)` donde:
# - `interes = capital * tasa * tiempo`
# - `monto_total = capital + interes`
#
# Los valores se redondean a 2 decimales.
#
# Si `capital <= 0`, `tasa < 0` o `tiempo < 0`, devuelve `(None, None)`.
#
# **Ejemplo:** `interes_simple(1000000, 0.05, 3)` → `(150000.0, 1150000.0)`
# (capital de 1M, tasa 5% anual, 3 años).

# %%
recibir capital, tasa y tiempo

si capital es menor o igual a 0,
  o tasa es menor que 0,
  o tiempo es menor que 0:
   guardar None en interes
   guardar None en monto_total
si no:
   guardar capital * tasa * tiempo en interes
   guardar capital + interes en monto_total

devolver (interes, monto_total)

# %%
def interes_simple(capital, tasa, tiempo):
    if capital <= 0 or tasa < 0 or tiempo < 0:
      interes = None
      monto_total = None
    else:
      interes = capital * tasa * tiempo
      monto_total = capital + interes
    return (interes,monto_total)

# %%
# === Tests visibles · Ejercicio 5 ===
assert interes_simple(1000000, 0.05, 3) == (150000.0, 1150000.0)
assert interes_simple(500000, 0.10, 1) == (50000.0, 550000.0)
print("✅ Ejercicio 5: tests visibles superados.")

# %%
# === Tests adicionales (ocultos) · Ejercicio 5 ===
assert interes_simple(0, 0.05, 3) == (None, None)
assert interes_simple(1000000, 0, 3) == (0.0, 1000000.0)
assert interes_simple(1000000, 0.05, 0) == (0.0, 1000000.0)
assert interes_simple(-1000, 0.05, 3) == (None, None)
print("✅ Ejercicio 5: tests adicionales superados.")

# %% [markdown]
# ## Ejercicio 6 · Divisible por 3 y por 5
#
# Implementa `divisible_3_y_5(n)` que devuelva `True` si `n` es divisible **simultáneamente** por 3 y por 5; `False` en caso contrario.
#
# **Ejemplos:** `divisible_3_y_5(15)` → `True`; `divisible_3_y_5(9)` → `False`; `divisible_3_y_5(30)` → `True`.

# %%
recibir n

si el residuo de n dividido entre 15 es igual a 0:
   devolver verdadero

devolver falso

# %%
def divisible_3_y_5(n):
  if n % 15 ==0:
    return True
  return False

# %%
# === Tests visibles · Ejercicio 6 ===
assert divisible_3_y_5(15) is True
assert divisible_3_y_5(9) is False
assert divisible_3_y_5(30) is True
print("✅ Ejercicio 6: tests visibles superados.")
# Out:
# ✅ Ejercicio 6: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 6 ===
assert divisible_3_y_5(0) is True
assert divisible_3_y_5(1) is False
assert divisible_3_y_5(45) is True
assert divisible_3_y_5(10) is False
assert divisible_3_y_5(6) is False
print("✅ Ejercicio 6: tests adicionales superados.")
# Out:
# ✅ Ejercicio 6: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 7 · Precio con descuento e IVA encadenados
#
# Implementa `precio_final(precio_original, descuento, tasa_iva)` que:
# 1. Aplica el descuento al precio original: `precio_desc = precio_original * (1 - descuento)`
# 2. Aplica el IVA sobre el precio con descuento: `final = precio_desc * (1 + tasa_iva)`
# 3. Devuelve una tupla `(precio_desc, final)` redondeada a 2 decimales.
#
# Si `precio_original <= 0` o `descuento < 0` o `descuento > 1` o `tasa_iva < 0`, devuelve `(None, None)`.
#
# **Ejemplo:** `precio_final(100000, 0.10, 0.19)` → `(90000.0, 107100.0)`.

# %%
recibir precio_original, descuento y tasa_iva

si precio_original es menor o igual a 0,
  o descuento es menor que 0,
  o descuento es mayor que 1,
  o tasa_iva es menor que 0:
   guardar None en precio_desc
   guardar None en final
si no:
   guardar precio_original * (1 - descuento) en precio_desc
   guardar precio_desc * (1 + tasa_iva) en final

devolver (precio_desc, final)

# %%
def precio_final(precio_original, descuento, tasa_iva):
    if precio_original <= 0 or descuento < 0 or descuento > 1 or tasa_iva < 0:
      precio_desc = None
      final = None
    else:
      precio_desc = precio_original * (1 - descuento)
      final = precio_desc * (1 + tasa_iva)
    return (precio_desc, final)

# %%
# === Tests visibles · Ejercicio 7 ===
assert precio_final(100000, 0.10, 0.19) == (90000.0, 107100.0)
assert precio_final(50000, 0, 0.19) == (50000.0, 59500.0)
print("✅ Ejercicio 7: tests visibles superados.")
# Out:
# ✅ Ejercicio 7: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 7 ===
assert precio_final(0, 0.10, 0.19) == (None, None)
assert precio_final(100000, -0.1, 0.19) == (None, None)
assert precio_final(100000, 1.5, 0.19) == (None, None)
assert precio_final(200000, 0.15, 0.08) == (170000.0, 183600.0)
print("✅ Ejercicio 7: tests adicionales superados.")
# Out:
# ✅ Ejercicio 7: tests adicionales superados.

# %% [markdown]
# ## Ejercicio 8 · Convertir segundos a horas, minutos y segundos
#
# Implementa `segundos_a_hms(total_segundos)` que convierta un número de segundos a una tupla `(horas, minutos, segundos)`.
#
# Usa solo división entera `//` y módulo `%`. Si `total_segundos < 0`, devuelve `(None, None, None)`.
#
# **Ejemplos:**
# - `segundos_a_hms(3661)` → `(1, 1, 1)` (1h 1m 1s)
# - `segundos_a_hms(90)` → `(0, 1, 30)` (0h 1m 30s)
# - `segundos_a_hms(0)` → `(0, 0, 0)`

# %%
recibir total_segundos

si total_segundos es menor que 0:
   guardar None en horas
   guardar None en minutos
   guardar None en segundos
si no:
   guardar total_segundos // 3600 en horas
   guardar (total_segundos % 3600) // 60 en minutos
   guardar (total_segundos % 3600) % 60 en segundos

devolver (horas, minutos, segundos)

# %%
def segundos_a_hms(total_segundos):
    if total_segundos < 0:
      horas = None
      minutos = None
      segundos = None
    else:
      horas = total_segundos // 3600
      minutos = (total_segundos % 3600)//60
      segundos = (total_segundos % 3600) %60
    return (horas, minutos, segundos)

# %%
# === Tests visibles · Ejercicio 8 ===
assert segundos_a_hms(3661) == (1, 1, 1)
assert segundos_a_hms(90)   == (0, 1, 30)
assert segundos_a_hms(0)    == (0, 0, 0)
print("✅ Ejercicio 8: tests visibles superados.")
# Out:
# ✅ Ejercicio 8: tests visibles superados.

# %%
# === Tests adicionales (ocultos) · Ejercicio 8 ===
assert segundos_a_hms(3600) == (1, 0, 0)
assert segundos_a_hms(86399) == (23, 59, 59)
assert segundos_a_hms(-1) == (None, None, None)
assert segundos_a_hms(9753) == (2, 42, 33)
print("✅ Ejercicio 8: tests adicionales superados.")
# Out:
# ✅ Ejercicio 8: tests adicionales superados.

# %% [markdown]
# ---
# ## Entrega
#
# Cuando todas las celdas de tests muestren ✅, has completado la tarea.
#
# | Ejercicio | Patrón principal |
# |---|---|
# | 1 Días entre años | bucle + operador % + condicional bisiesto |
# | 2 Tipo triángulo | múltiples condicionales + operadores lógicos |
# | 3 Índice de rentabilidad | operadores aritméticos + validación |
# | 4 Clasificar nota | condicional escalonado + caso borde |
# | 5 Interés simple | aritmética básica + validación de entradas |
# | 6 Divisible por 3 y 5 | operador % + and lógico |
# | 7 Descuento + IVA | aritmética encadenada + validación |
# | 8 Segundos a HH:MM:SS | operadores // y % anidados |
#
# > 💭 **Reflexión:** los ejercicios 6, 7 y 8 ilustran que la mayoría de
# > los problemas "de negocios" son, en el fondo, problemas de aritmética
# > y lógica booleana. La próxima clase añadiremos bucles para manejar
# > *colecciones* de datos.
